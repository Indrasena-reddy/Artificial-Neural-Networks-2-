# %%
# define function cnn_train so that it can be run from this cell
from CNN_S1 import cnn_train

# user paramters
out_channels = [11,8]  # list of number of output channels to be used in the cnn blocks
epochs = 15# number of epochs
batch_size = 30  # training batch size
learning_rate = 0.3  # learning rate
cuda = True  # true or false to train the model on cuda or not
plots = True  # true or false to produce plots of train and test losses and accuracies

# train and evaluate mlp_model
cnn_model, losses = cnn_train(out_channels, epochs, batch_size, learning_rate, cuda, plots)
print(cnn_model)
# Out:
# Epoch:  1
# Epoch:  2
# Epoch:  3
# Epoch:  4
# Epoch:  5
# Epoch:  6
# Epoch:  7
# Epoch:  8
# Epoch:  9
# Epoch:  10
# Epoch:  11
# Epoch:  12
# Epoch:  13
# Epoch:  14
# Epoch:  15
# Executed Device:  cuda:0
# Sequential(
#   (0): Conv2d(1, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU()
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Conv2d(11, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): ReLU()
#   (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Flatten(start_dim=1, end_dim=-1)
#   (7): Linear(in_features=392, out_features=500, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
# Evaluating Accuracy from the result of 10000 random picks
from CNN_S1 import accuracy
import random

av =[]
ni = 100
for j in range(ni):
    ind = []
    for i in range(100):
        n = random.randint(0,9999)
        ind.append(n)        
    av.append(accuracy(cnn_model,ind))
print("Accuracy: ",sum(av)/ni,' %')
# Out:
# Accuracy:  89.47  %

# %%
# define function mlp_train so that it can be run from this cell
from CNN_S1 import cnn_apply

# user parameters
test_indexes = [11, 12, 13, 14, 15, 16, 17, 18, 19, 10]  # list of 10 indexes - examples to extract from test set
#test_indexes =[i * 70 for i in test_indexes ]
cnn_apply(cnn_model,test_indexes)
# Out:
# True Label:  9 ( Ankle boot )
# Predicted Label:  9 ( Ankle boot )
# True Label:  2 ( Pullover )
# Predicted Label:  2 ( Pullover )
# True Label:  1 ( Trouser )
# Predicted Label:  1 ( Trouser )
# True Label:  1 ( Trouser )
# Predicted Label:  1 ( Trouser )
# True Label:  6 ( Shirt )
# Predicted Label:  6 ( Shirt )
# True Label:  1 ( Trouser )
# Predicted Label:  1 ( Trouser )
# True Label:  4 ( Coat )
# Predicted Label:  4 ( Coat )
# True Label:  6 ( Shirt )
# Predicted Label:  6 ( Shirt )
# True Label:  5 ( Sandal )
# Predicted Label:  5 ( Sandal )
# True Label:  7 ( Sneaker )
# Predicted Label:  7 ( Sneaker )
# 10 / 10
